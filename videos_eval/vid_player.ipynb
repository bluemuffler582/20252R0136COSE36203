# %%
from IPython.display  import  Video 
Video("ppo_demo_Humanoid-v5_dur5s.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
