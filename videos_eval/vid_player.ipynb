# %%
pwd
# Out:
# '/home/ec2-user/SageMaker/new_robotics/PPO-Humanoid/videos_eval'

# %%
from IPython.display import Video 
Video("ppo_demo_HumanoidTurnLeft-v0_dur4s.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
